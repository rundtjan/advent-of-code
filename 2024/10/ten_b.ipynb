# %%
filename = 'big_map.txt'

with open(filename) as f:
    map = f.readlines()
    map = [x[:len(x) - 1] for x in [list(x) for x in map]]

map
# Out:
# [['0',
#   '1',
#   '2',
#   '3',
#   '4',
#   '5',
#   '0',
#   '1',
#   '2',
#   '8',
#   '9',
#   '4',
#   '5',
#   '2',
#   '1',
#   '2',
#   '4',
#   '3',
#   '4',
#   '4',
#   '9',
#   '8',
#   '1',
#   '0',
#   '7',
#   '6',
#   '5',
#   '4',
#   '8',
#   '7',
#   '6',
#   '2',
#   '1',
#   '2',
#   '3',
#   '2',
#   '2',
#   '3',
#   '4',
#   '5',
#   '4',
#   '3',
#   '2',
#   '1',
#   '1',
#   '0',
#   '7',
#   '8',
#   '7',
#   '8',
#   '7',
#   '0',
#   '1',
#   '2',
#   '3'],
#  ['1',
#   '2',
#   '1',
#   '4',
#   '5',
#   '6',
#   '3',
#   '2',
#   '8',
#   '7',
#   '6',
#   '5',
#   '4',
#   '3',
#   '0',
#   '2',
#   '3',
#   '4',
#   '5',
#   '3',
#   '4',
#   '7',
#   '2',
#   '7',
#   '8',
#   '9',
#   '2',
#   '3',
#   '9',
#   '4',
#   '5',
#   '0',
#   '0',
#   '3',
#   '4',
#   '1',
#   '1',
#   '2',
#   '7',
#   '6',
#   '7',
#   '4',
#   '1',
#   '0',
#   '2',
#   '5',
#   '6',
#   '9',
#   '6',
#   '9',
#   '8',
#   '3',
#   '2',
#   '5',
#   '4'],
# ...

# %%
zeros = []
for arr in map:
    temp = []
    for elem in map[0]:
        temp.append(set())
    zeros.append(temp[:])
zeros
# Out:
# [[set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
# ...

# %%
levels = list(range(10))
levels.reverse()

starts = list(range(1000))
starts.reverse()

for y in range(len(map)):
    for x in range(len(map[0])):
        if map[y][x] == '9':
            zeros[y][x].add(starts.pop())
            
            
def inside_of_map(y, x):
    if 0 <= x <= len(map[0]) - 1 and 0 <= y <= len(map) - 1:
        return True
    return False


def spread_around(y, x, val, level):
    for py in [-1, 1]:
        if inside_of_map(y+py, x) and int(map[y+py][x]) == level - 1:
            for v in val:
                zeros[y+py][x].add(v)
    for px in [-1, 1]:
        if inside_of_map(y, x+px) and int(map[y][x+px]) == level - 1:
            for v in val:
                zeros[y][x + px].add(v)


def draw_zeros():
    print('-----------------------------')
    for row in zeros:
        print(row)

for level in levels:
    draw_zeros()
    for y in range(len(map)):
        for x in range(len(map[0])):
            if int(map[y][x]) == level:
                own_value = zeros[y][x]
                spread_around(y,x, own_value, level)
                    
zeros
# Out:
# -----------------------------
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {0}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {1}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {2}, set(), set(), {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {4}, set(), {5}, set(), set(), set(), set(), set()]
# ...

# %%
sum = 0

for y in range(len(map)):
    for x in range(len(map[0])):
        if map[y][x] == '0':
            sum += len(zeros[y][x])

sum
# Out:
# 820
